# %% [markdown]
# ## Work
# 1. 請嘗試寫一個 callback 用來記錄各類別在訓練過程中，對驗證集的 True Positive 與 True Negative

# %%
import os
import keras

# Disable GPU
os.environ["CUDA_VISIBLE_DEVICES"] = ""
# Out:
# Using TensorFlow backend.

# %%
train, test = keras.datasets.cifar10.load_data()

# %%
## 資料前處理
def preproc_x(x, flatten=True):
    x = x / 255.
    if flatten:
        x = x.reshape((len(x), -1))
    return x

def preproc_y(y, num_classes=10):
    if y.shape[-1] == 1:
        y = keras.utils.to_categorical(y, num_classes)
    return y

# %%
x_train, y_train = train
x_test, y_test = test

# Preproc the inputs
x_train = preproc_x(x_train)
x_test = preproc_x(x_test)

# Preprc the outputs
y_train = preproc_y(y_train)
y_test = preproc_y(y_test)

# %%
from keras.layers import BatchNormalization

def build_mlp(input_shape, output_units=10, num_neurons=[512, 256, 128]):
    input_layer = keras.layers.Input(input_shape)
    
    for i, n_units in enumerate(num_neurons):
        if i == 0:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(input_layer)
            x = BatchNormalization()(x)
        else:
            x = keras.layers.Dense(units=n_units, 
                                   activation="relu", 
                                   name="hidden_layer"+str(i+1))(x)
            x = BatchNormalization()(x)
    
    out = keras.layers.Dense(units=output_units, activation="softmax", name="output")(x)
    
    model = keras.models.Model(inputs=[input_layer], outputs=[out])
    return model

# %%
## 超參數設定
LEARNING_RATE = 1e-3
EPOCHS = 25
BATCH_SIZE = 1024
MOMENTUM = 0.95

# %%
# 載入 Callbacks
 
from keras.callbacks import Callback
from sklearn.metrics import f1_score

# class f1sc(Callback):
#     def on_train_begin(self, epoch, logs = {}):
#         logs = logs or {}
#         record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
#         for i in record_items:
#             if i not in self.params['metrics']:
#                 self.params['metrics'].append(i)
    
#     def on_epoch_end(self, epoch, logs = {}, thres=0.5):
#         logs = logs or {}
#         y_true = self.validation_data[1].argmax(axis = 1)
#         y_pred = self.model.predict(self.validation_data[0])
#         y_pred = (y_pred[:, 1] >= thres) * 1
        
#         logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")
        
# log_f1sc = f1sc()


def tp_tn(y_true,y_pred):
    TP = 0
    TN = 0
    for i in range(len(y_true)):
        if y_true[i] == y_pred[i] == 1:
            TP += 1
        if y_true[i] == y_pred[i] == 0:
            TN += 1
    return (TP,TN)


# # Record_fp_tp
class Record_tp_tn(Callback):
    def on_train_begin(self, epoch, logs = {}):
        logs = logs or {}
        record_items = ["val_auc", "val_f1sc", "val_fp", "val_fn", "val_tp", "val_tn"]
        for i in record_items:
            if i not in self.params['metrics']:
                self.params['metrics'].append(i)
    
    def on_epoch_end(self, epoch, logs = {}, thres=0.5):
        logs = logs or {}
        y_true = self.validation_data[1].argmax(axis = 1)
        y_pred = self.model.predict(self.validation_data[0])
        y_pred = (y_pred[:, 1] >= thres) * 1
        
        logs["val_f1sc"] = f1_score(y_true = y_true, y_pred = y_pred, average="weighted")
        
        logs['val_tp'],logs['val_tn'] = tp_tn(y_true,y_pred)
         
    
    
    """Code Here
    撰寫一個紀錄 ture positive 與 true negative 數量的 callbacks    
    """
        
rec_tptn = Record_tp_tn()

# %%
# model = build_mlp(input_shape=x_train.shape[1:])
# model.summary()
# optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
# model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

# model.fit(x_train, y_train, 
#           epochs=EPOCHS, 
#           batch_size=BATCH_SIZE, 
#           validation_data=(x_test, y_test), 
#           shuffle=True,
#           callbacks=[log_f1sc]
#          )

# # Collect results
# train_loss = model.history.history["loss"]
# valid_loss = model.history.history["val_loss"]
# train_acc = model.history.history["accuracy"]
# valid_acc = model.history.history["val_accuracy"]

# # 在訓練後，將 f1sc 紀錄調出
# valid_f1sc = model.history.history['val_f1sc']



model = build_mlp(input_shape=x_train.shape[1:])
model.summary()
optimizer = keras.optimizers.SGD(lr=LEARNING_RATE, nesterov=True, momentum=MOMENTUM)
model.compile(loss="categorical_crossentropy", metrics=["accuracy"], optimizer=optimizer)

"""Code Here
將 callbacks 放入模型訓練流程中
"""
model.fit(x_train, y_train, 
          epochs=EPOCHS, 
          batch_size=BATCH_SIZE, 
          validation_data=(x_test, y_test),
          shuffle=True,
          callbacks=[rec_tptn])

# Collect results
train_loss = model.history.history["loss"]
valid_loss = model.history.history["val_loss"]
train_acc = model.history.history["accuracy"]
valid_acc = model.history.history["val_accuracy"]

"""Code Here
將 tp/tn 從訓練完的模型中取出
"""
valid_tp = model.history.history['val_tp']
valid_tn = model.history.history['val_tn']
# Out:
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         (None, 3072)              0
# _________________________________________________________________
# hidden_layer1 (Dense)        (None, 512)               1573376
# _________________________________________________________________
# batch_normalization_10 (Batc (None, 512)               2048
# _________________________________________________________________
# hidden_layer2 (Dense)        (None, 256)               131328
# _________________________________________________________________
# batch_normalization_11 (Batc (None, 256)               1024
# _________________________________________________________________
# hidden_layer3 (Dense)        (None, 128)               32896
# _________________________________________________________________
# batch_normalization_12 (Batc (None, 128)               512
# _________________________________________________________________
# output (Dense)               (None, 10)                1290
# =================================================================
# Total params: 1,742,474
# Trainable params: 1,740,682
# Non-trainable params: 1,792
# _________________________________________________________________
# Train on 50000 samples, validate on 10000 samples
# Epoch 1/25
# 50000/50000 [==============================] - 3s 60us/step - loss: 2.2131 - accuracy: 0.2741 - val_loss: 2.1479 - val_accuracy: 0.2241
# Epoch 2/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.7326 - accuracy: 0.3957 - val_loss: 1.9498 - val_accuracy: 0.3127
# Epoch 3/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.6105 - accuracy: 0.4372 - val_loss: 1.8436 - val_accuracy: 0.3531
# Epoch 4/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.5381 - accuracy: 0.4628 - val_loss: 1.7247 - val_accuracy: 0.4026
# Epoch 5/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.4829 - accuracy: 0.4810 - val_loss: 1.6534 - val_accuracy: 0.4166
# Epoch 6/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.4394 - accuracy: 0.4960 - val_loss: 1.6065 - val_accuracy: 0.4317
# Epoch 7/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.3999 - accuracy: 0.5104 - val_loss: 1.5475 - val_accuracy: 0.4539
# Epoch 8/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.3624 - accuracy: 0.5244 - val_loss: 1.5213 - val_accuracy: 0.4615
# Epoch 9/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.3314 - accuracy: 0.5346 - val_loss: 1.5042 - val_accuracy: 0.4658
# Epoch 10/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.3018 - accuracy: 0.5463 - val_loss: 1.4986 - val_accuracy: 0.4693
# Epoch 11/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.2751 - accuracy: 0.5572 - val_loss: 1.4862 - val_accuracy: 0.4743
# Epoch 12/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.2471 - accuracy: 0.5675 - val_loss: 1.4777 - val_accuracy: 0.4765
# Epoch 13/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.2200 - accuracy: 0.5769 - val_loss: 1.4689 - val_accuracy: 0.4809
# Epoch 14/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.1950 - accuracy: 0.5874 - val_loss: 1.4766 - val_accuracy: 0.4841
# Epoch 15/25
# 50000/50000 [==============================] - 3s 52us/step - loss: 1.1737 - accuracy: 0.5956 - val_loss: 1.4628 - val_accuracy: 0.4853
# Epoch 16/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.1499 - accuracy: 0.6045 - val_loss: 1.4613 - val_accuracy: 0.4849
# Epoch 17/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.1286 - accuracy: 0.6122 - val_loss: 1.4517 - val_accuracy: 0.4872
# Epoch 18/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 1.1022 - accuracy: 0.6217 - val_loss: 1.4516 - val_accuracy: 0.4931
# Epoch 19/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.0799 - accuracy: 0.6309 - val_loss: 1.4494 - val_accuracy: 0.4884
# Epoch 20/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.0587 - accuracy: 0.6396 - val_loss: 1.4532 - val_accuracy: 0.4915
# Epoch 21/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.0352 - accuracy: 0.6471 - val_loss: 1.4466 - val_accuracy: 0.4935
# Epoch 22/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 1.0150 - accuracy: 0.6558 - val_loss: 1.4528 - val_accuracy: 0.4938
# Epoch 23/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.9946 - accuracy: 0.6630 - val_loss: 1.4539 - val_accuracy: 0.4903
# Epoch 24/25
# 50000/50000 [==============================] - 3s 51us/step - loss: 0.9738 - accuracy: 0.6707 - val_loss: 1.4688 - val_accuracy: 0.4868
# Epoch 25/25
# 50000/50000 [==============================] - 3s 50us/step - loss: 0.9524 - accuracy: 0.6806 - val_loss: 1.4598 - val_accuracy: 0.4947

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_f1sc)), valid_f1sc, label="valid f1-score")
plt.legend()
plt.title("F1-score")
plt.show()

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

plt.plot(range(len(train_loss)), train_loss, label="train loss")
plt.plot(range(len(valid_loss)), valid_loss, label="valid loss")
plt.legend()
plt.title("Loss")
plt.show()

plt.plot(range(len(train_acc)), train_acc, label="train accuracy")
plt.plot(range(len(valid_acc)), valid_acc, label="valid accuracy")
plt.legend()
plt.title("Accuracy")
plt.show()

plt.plot(range(len(valid_tp)), valid_tp, label="valid tp", color="navy")
plt.plot(range(len(valid_tn)), valid_tn, label="valid tn", color="red")
plt.legend()
plt.title("True positives and True Negatives")
plt.show()
